# %%
import pandas as pd
import numpy as np
import multiprocessing
from scipy import stats
import timeit
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import scale
# %matplotlib inline
import matplotlib.pyplot as plt
#import aux_functions
#from aux_functions import plot_with_err

# %% [markdown]
# # Import data

# %% [markdown]
# ##Train

# %%
data = pd.read_csv('/content/total_merged_train.csv')
data = data.drop(columns=['customerid'] + ['systemloanid'])
y = data['good_bad_flag']

# %% [markdown]
# Dummies

# %%
dummy_int = pd.get_dummies(data[['interest_interval']])
dummy_bank_name = pd.get_dummies(data[['bank_name_clients']], drop_first=True)
dummy_td = pd.get_dummies(data[['termdays']], drop_first=True)
dummy_age = pd.get_dummies(data[['age_interval']])
dummy_state = pd.get_dummies(data[['state']], drop_first=True)
dummy_loan = pd.get_dummies(data[['loan_interval']], drop_first=True)
dummy_loannum = pd.get_dummies(data[['loannumber']], drop_first=True)

X = pd.concat([data, dummy_int, dummy_bank_name, dummy_td, dummy_age, dummy_state, dummy_loan, dummy_loannum], axis=1)
X = X.drop(['interest_interval','bank_name_clients', 'termdays', 'age_interval','state','loan_interval','loannumber', 'good_bad_flag'], 1)

X.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   # Remove the CWD from sys.path while we load stuff.
#    loanamount  interest  avg_loanamount  avg_paym_span_hrs  \
# 0     10000.0    3000.0    10000.000000           0.000000
# 1     10000.0    3000.0    10000.000000          13.000000
# 2     20000.0    3000.0    15000.000000          15.166667
# 3     20000.0    4500.0    10000.000000          13.666667
# 4     20000.0    4500.0    12727.272727          11.636364
#
#    avg_active_span_days  avg_interest  max_loannumber   age  \
# 0             33.000000   3000.000000             1.0  36.0
# 1              3.000000   3000.000000             1.0  41.0
# 2             23.333333   3133.333333             6.0  34.0
# 3             25.333333   3000.000000             3.0  47.0
# 4             14.000000   1559.090909            11.0  27.0
#
#    interest_interval_3000  interest_interval_mas de 3000  \
# 0                       1                              0
# 1                       1                              0
# 2                       1                              0
# 3                       0                              1
# 4                       0                              1
#
#    interest_interval_menos de 3000  bank_name_clients_Multinational Banks  \
# 0                                0                                      1
# 1                                0                                      0
# 2                                0                                      1
# 3                                0                                      0
# 4                                0                                      1
#
#    termdays_Other  age_interval_26-35  age_interval_36-40  age_interval_41-61  \
# 0               0                   0                   1                   0
# 1               0                   0                   0                   1
# 2               0                   1                   0                   0
# 3               0                   0                   0                   1
# 4               0                   1                   0                   0
#
#    state_Other  loan_interval_mas de 10000  loannumber_0-4
# 0            0                           0               1
# 1            0                           0               1
# 2            1                           1               0
# 3            1                           1               1
# 4            1                           1               0

# %% [markdown]
# Tipificamos

# %%
X_scale = pd.DataFrame(scale(X))
X_scale.columns = X.columns
X = X_scale
X.columns = X_scale.columns
X.head()
# Out:
#    loanamount  interest  avg_loanamount  avg_paym_span_hrs  \
# 0   -0.733215 -0.285638       -0.608786          -3.179329
# 1   -0.733215 -0.285638       -0.608786           0.004068
# 2    0.194972 -0.285638        0.439597           0.534634
# 3    0.194972  0.600455       -0.608786           0.167319
# 4    0.194972  0.600455       -0.036941          -0.329855
#
#    avg_active_span_days  avg_interest  max_loannumber       age  \
# 0              1.276814      0.330176       -0.876227 -0.060081
# 1             -2.268915      0.330176       -0.876227 -0.059547
# 2              0.134301      0.491189        0.487956 -0.060294
# 3              0.370683      0.330176       -0.330554 -0.058906
# 4             -0.968814     -1.409862        1.852139 -0.061042
#
#    interest_interval_3000  interest_interval_mas de 3000  \
# 0                1.260701                      -0.783287
# 1                1.260701                      -0.783287
# 2                1.260701                      -0.783287
# 3               -0.793209                       1.276672
# 4               -0.793209                       1.276672
#
#    interest_interval_menos de 3000  bank_name_clients_Multinational Banks  \
# 0                        -0.552029                               0.806211
# 1                        -0.552029                              -1.240371
# 2                        -0.552029                               0.806211
# 3                        -0.552029                              -1.240371
# 4                        -0.552029                               0.806211
#
#    termdays_Other  age_interval_26-35  age_interval_36-40  age_interval_41-61  \
# 0       -0.613458           -0.748083            1.456264           -0.687158
# 1       -0.613458           -0.748083           -0.686689            1.455270
# 2       -0.613458            1.336749           -0.686689           -0.687158
# 3       -0.613458           -0.748083           -0.686689            1.455270
# 4       -0.613458            1.336749           -0.686689           -0.687158
#
#    state_Other  loan_interval_mas de 10000  loannumber_0-4
# 0    -1.065516                   -0.890780        0.884886
# 1    -1.065516                   -0.890780        0.884886
# 2     0.938513                    1.122611       -1.130089
# 3     0.938513                    1.122611        0.884886
# 4     0.938513                    1.122611       -1.130089

# %%
#dimensión del conjunto de train
n_train = int(X.shape[0])

#selección del conjunto de train
X_train = X.iloc[:n_train]
y_train = y.iloc[:n_train]

# %% [markdown]
# ## Validation y Test

# %%
data_t = pd.read_csv('/content/total_merged_test.csv')
data_t = data_t.drop(columns=['customerid'] + ['systemloanid'])
y_t = data_t['good_bad_flag']

# %% [markdown]
# Dummies

# %%
dummy_int = pd.get_dummies(data_t[['interest_interval']])
dummy_bank_name = pd.get_dummies(data_t[['bank_name_clients']], drop_first=True)
dummy_td = pd.get_dummies(data_t[['termdays']], drop_first=True)
dummy_age = pd.get_dummies(data_t[['age_interval']])
dummy_state = pd.get_dummies(data_t[['state']], drop_first=True)
dummy_loan = pd.get_dummies(data_t[['loan_interval']], drop_first=True)
dummy_loannum = pd.get_dummies(data_t[['loannumber']], drop_first=True)

X_t = pd.concat([data_t, dummy_int, dummy_bank_name, dummy_td, dummy_age, dummy_state, dummy_loan, dummy_loannum], axis=1)
X_t = X_t.drop(['interest_interval','bank_name_clients', 'termdays', 'age_interval','state','loan_interval','loannumber','good_bad_flag'], 1)

X_t.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   # Remove the CWD from sys.path while we load stuff.
#    loanamount  interest  avg_loanamount  avg_paym_span_hrs  \
# 0     20000.0    4500.0         14000.0               12.8
# 1     10000.0    3000.0         10000.0               13.0
# 2     10000.0    3000.0         10000.0                7.0
# 3     10000.0    3000.0         10000.0               18.0
# 4     20000.0    4500.0         14000.0                9.0
#
#    avg_active_span_days  avg_interest  max_loannumber   age  \
# 0                  19.0        2700.0             5.0  39.0
# 1                  29.0        3000.0             2.0  42.0
# 2                  57.0        3000.0             1.0  45.0
# 3                  14.0        1500.0             1.0  40.0
# 4                  19.6        2700.0             5.0  37.0
#
#    interest_interval_3000  interest_interval_mas de 3000  \
# 0                       0                              1
# 1                       1                              0
# 2                       1                              0
# 3                       1                              0
# 4                       0                              1
#
#    interest_interval_menos de 3000  bank_name_clients_Multinational Banks  \
# 0                                0                                      1
# 1                                0                                      1
# 2                                0                                      0
# 3                                0                                      1
# 4                                0                                      1
#
#    termdays_Other  age_interval_26-35  age_interval_36-40  age_interval_41-61  \
# 0               0                   0                   1                   0
# 1               0                   0                   0                   1
# 2               0                   0                   0                   1
# 3               0                   0                   1                   0
# 4               0                   0                   1                   0
#
#    state_Other  loan_interval_mas de 10000  loannumber_0-4
# 0            1                           1               0
# 1            1                           0               1
# 2            1                           0               1
# 3            0                           0               1
# 4            0                           1               0

# %% [markdown]
# Tipificamos

# %%
X_t_scale = pd.DataFrame(scale(X_t))
X_t_scale.columns = X_t.columns
X_t = X_t_scale
X_t.columns = X_t_scale.columns
X_t.head()
# Out:
#    loanamount  interest  avg_loanamount  avg_paym_span_hrs  \
# 0    0.232470  0.678767        0.257389          -0.084439
# 1   -0.736634 -0.233861       -0.596311          -0.036304
# 2   -0.736634 -0.233861       -0.596311          -1.480364
# 3   -0.736634 -0.233861       -0.596311           1.167079
# 4    0.232470  0.678767        0.257389          -0.999010
#
#    avg_active_span_days  avg_interest  max_loannumber       age  \
# 0             -0.289372      0.072892        0.293053 -0.048716
# 1              0.865412      0.425222       -0.566660 -0.048324
# 2              4.098808      0.425222       -0.853231 -0.047932
# 3             -0.866764     -1.336431       -0.853231 -0.048585
# 4             -0.220085      0.072892        0.293053 -0.048978
#
#    interest_interval_3000  interest_interval_mas de 3000  \
# 0               -0.755045                       1.310895
# 1                1.324424                      -0.762837
# 2                1.324424                      -0.762837
# 3                1.324424                      -0.762837
# 4               -0.755045                       1.310895
#
#    interest_interval_menos de 3000  bank_name_clients_Multinational Banks  \
# 0                        -0.606694                               0.758937
# 1                        -0.606694                               0.758937
# 2                        -0.606694                              -1.317633
# 3                        -0.606694                               0.758937
# 4                        -0.606694                               0.758937
#
#    termdays_Other  age_interval_26-35  age_interval_36-40  age_interval_41-61  \
# 0       -0.662085           -0.770667            1.468977           -0.671399
# 1       -0.662085           -0.770667           -0.680746            1.489426
# 2       -0.662085           -0.770667           -0.680746            1.489426
# 3       -0.662085           -0.770667            1.468977           -0.671399
# 4       -0.662085           -0.770667            1.468977           -0.671399
#
#    state_Other  loan_interval_mas de 10000  loannumber_0-4
# 0     0.928724                    1.113553       -1.189030
# 1     0.928724                   -0.898027        0.841021
# 2     0.928724                   -0.898027        0.841021
# 3    -1.076747                   -0.898027        0.841021
# 4    -1.076747                    1.113553       -1.189030

# %% [markdown]
# Dividimos el dataset de test en validation y test, es decir, 50-50. Representarán el 10% del dataset total cada uno, ya que el train supone un 80% del total de los datos.

# %%
perc_values = [0.5, 0.5]

# dimensiones de los conjuntos de validation y test
n_val = int(X_t.shape[0] * perc_values[0])
n_test = int(X_t.shape[0] * perc_values[1])

# selección del conjunto de validación
X_val = X_t.iloc[:n_val]
y_val = y_t.iloc[:n_val]

# selección del conjunto de test
X_test = X_t.iloc[n_test:]
y_test = y_t.iloc[n_test:]

# %%
#Visualizamos el tamaño de los tres tipos de datasets

print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))
print('Test data size = ' + str(X_test.shape))
print('Test target size = ' + str(y_test.shape))
# Out:
# Train data size = (3361, 19)
# Train target size = (3361,)
# Validation data size = (420, 19)
# Validation target size = (420,)
# Test data size = (420, 19)
# Test target size = (420,)

# %% [markdown]
# #Search Grid

# %%
#Hemos decidido probar los siguientes modelos:
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
#Importamos la métrica que evaluará nuestros modelos
from sklearn.metrics import roc_auc_score as metric

# %% [markdown]
# ## Parámetros generales

# %%
random_state = 42    # inicializa el random number generator interno
nthread = multiprocessing.cpu_count() - 1
scale_pos_weight = sum(y_train == 0) / sum(y_train == 1)

# %%
#puntos recomendados por Cherkassky para la SVM

n = X_train.shape[0]
d = X_train.shape[1]
m = np.mean(y_train)
s = np.std(y_train)
C_cherk = np.max([np.abs(m + 3*s),np.abs(m - 3*s)])
gamma_cherk = np.power(0.2, 1/d)

# %% [markdown]
# ## Definición del grid

# %%
# Regresion Logística
regularization_values = ['l1', 'l2', 'none']   #reduce overfitting
penalty_values = [1, 10, 100]   #penaliza por tener demasiadas variables

# SVM
C_values = [C_cherk, 5e-03, 4.5e-03, 4e-03]    #parámetro de regularización 
gamma_kernel_values = [gamma_cherk, 3.26e-09, 3.255e-09, 3.25e-09]    #influencia del train

# Random Forest
ntrees_values = [10, 100, 1000]
max_depth_values = [None, 6, 20];
min_samples_split_values = [2, 5, 20];
min_samples_leaf_values = [1, 5, 20];
max_features_values = [None, 1, 2];

# Xgboost
nrounds_values = [10, 100]
eta_values = [0.3, 0.99]
gamma_values = [0, 1]
max_depth_values = [6, 20]
min_child_weight_values = [1, 20]
subsample_values = [0.1, 1]
colsample_bytree_values = [0.1, 1]
num_parallel_tree_values = [1, 20]
lambda_values = [0, 1]
alpha_values = [0, 1]

# %%
params_values = [{'model': 'logistic regression',
                  'regularization': regularization_values,
                 'penalty': penalty_values},

                 {'model': 'svm',
                  'C': C_values,
                 'gamma_kernel': gamma_kernel_values},

                 {'model': 'random forest',
                  'n_trees': ntrees_values,
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},

                 {'model': 'xgboost',
                  'nrounds': nrounds_values,
                  'eta': eta_values,
                 'gamma': gamma_values,
                 'max_depth': max_depth_values,
                 'min_child_weight': min_child_weight_values,
                 'subsample': subsample_values,
                 'colsample_bytree': colsample_bytree_values,
                 'num_parallel_tree': num_parallel_tree_values,
                 'lambda': lambda_values,
                 'alpha': alpha_values}]

# %%
total_iteraciones = 0
for params in params_values:
    if params['model'] == 'logistic regression':
        n = len(params['regularization'])*len(params['penalty'])
    elif params['model'] == 'svm':
        n = len(params['C'])*len(params['gamma_kernel'])
    elif params['model'] == 'random forest':
        n = len(params['n_trees'])*len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'xgboost':
        n = len(params['nrounds'])*len(params['eta'])*len(params['gamma'])*len(params['max_depth'])*len(params['min_child_weight'])*len(params['subsample'])*len(params['colsample_bytree'])*len(params['num_parallel_tree'])*len(params['lambda'])*len(params['alpha'])
    total_iteraciones = total_iteraciones + n;
    print(str(n)+ ' iteraciones de ' + str(params['model']))
print(str(total_iteraciones)+ ' iteraciones en total')
# Out:
# 9 iteraciones de logistic regression
# 16 iteraciones de svm
# 162 iteraciones de random forest
# 1024 iteraciones de xgboost
# 1211 iteraciones en total

# %% [markdown]
# ## Aplicamos modelos

# %%
grid_results = pd.DataFrame();
num_iter = 0
for params in params_values:
  
    #Regresion Logística
    if params['model'] == 'logistic regression':
        for regularization in params['regularization']:
            for penalty in params['penalty']:  
                start = timeit.default_timer()
                num_iter += 1
                print('Inicio de iteracion ' + str(num_iter) + '. Regularizacion = ' + str(regularization) + ', Lambda = '  + str(penalty) + '\n')
                
                #Entrenar modelo
                if regularization == 'l1':
                    model = LogisticRegression(penalty = regularization, solver = 'liblinear', C = penalty, random_state = random_state)
                else:
                    model = LogisticRegression(penalty = regularization,solver = 'lbfgs', C = penalty, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                #Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                #Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])
                time = timeit.default_timer() - start

                print('Fin de iteracion ' + str(num_iter) + '. Regularizacion = ' + str(regularization) + ', Lambda = '  + str(penalty) +
                      '. AUC train = '  + str(auc_train) + ' -  AUC val = '  + str(auc_val)  + ' -  time = '  + str(time)  + '\n')
                
                grid_results = grid_results.append(pd.DataFrame(data={'model':'Logistic Regression',
                                                                      'params': [{'regularization':[regularization], 'penalty':[penalty]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val],
                                                                      'time':[time]},
                                                               columns=['model','params', 'auc_train', 'auc_val', 'time']), ignore_index=True)
                
    #SVM
    if params['model'] == 'svm':
        for C in params['C']:
            for gamma_kernel in params['gamma_kernel']:  
                start = timeit.default_timer()
                num_iter += 1
                print('Inicio de iteracion ' + str(num_iter) + '. C = ' + str(C) + ', gamma = '  + str(gamma_kernel) + '\n')
                
                #Entrenar modelo               
                model = SVC(C = C, gamma = gamma_kernel, probability = True, random_state = random_state)
                model.fit(X_train, np.array(y_train))

                #Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                #Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])
                time = timeit.default_timer() - start

                print('Fin de iteracion ' + str(num_iter) + '. C = ' + str(C) + ', gamma = '  + str(gamma_kernel) + 
                      '. AUC train = '  + str(auc_train) + ' -  AUC val = '  + str(auc_val)  + ' -  time = '  + str(time)  + '\n')
                
                grid_results = grid_results.append(pd.DataFrame(data={'model':'SVM',
                                                                     'params': [{'C':[C], 'gamma_kernel':[gamma_kernel]}],
                                                                      'auc_train':[auc_train], 'auc_val':[auc_val], 'time':[time]},
                                                               columns=['model','params', 'auc_train', 'auc_val', 'time']), ignore_index=True)
                

    #Random Forest
    if params['model'] == 'random forest':
        for n_trees in params['n_trees']:
            for max_depth in params['max_depth']:
                for min_samples_split in params['min_samples_split']:  
                    for min_samples_leaf in params['min_samples_leaf']:  
                        for max_features in params['max_features']:  
                            start = timeit.default_timer()
                            num_iter += 1 
                            print('Inicio de iteracion ' + str(num_iter) + '. n_trees = ' + str(n_trees) + ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) + ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) + '\n')

                            #Entrenar modelo               
                            model = RandomForestClassifier(n_estimators = n_trees, max_depth = max_depth,
                                                          min_samples_split = min_samples_split,
                                                          min_samples_leaf = min_samples_leaf,
                                                          max_features = max_features, random_state = random_state)

                            model.fit(X_train, np.array(y_train))

                            #Generar predicciones
                            pred_train_p = model.predict_proba(X_train)
                            pred_val_p = model.predict_proba(X_val)

                            #Calcular métricas de evaluación
                            auc_train = metric(y_train, pred_train_p[:, 1])
                            auc_val = metric(y_val, pred_val_p[:, 1])  
                            time = timeit.default_timer() - start

                            print('Fin de iteracion ' + str(num_iter) + '. n_trees = ' + str(n_trees) + ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) + ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) + '. AUC train = '  + str(auc_train) +  ' -  AUC val = '  + str(auc_val)  + 
                                  ' -  time = '  + str(time)  + '\n')
                            
                            grid_results = grid_results.append(pd.DataFrame(data={'model':'random forest',
                                                                                  'params': [{'n_trees':[n_trees],'max_depth':[max_depth],
                                                                                              'min_samples_split':[min_samples_split],
                                                                                              'min_samples_leaf':[min_samples_leaf],
                                                                                              'max_features':[max_features]}],
                                                                                  'auc_train':[auc_train], 
                                                                                  'auc_val':[auc_val],
                                                                                  'time':[time]},
                                                                           columns=['model','params', 'auc_train', 'auc_val', 'time']), ignore_index=True)  
    #XGBOOST
    if params['model'] == 'xgboost':
         for nrounds in params['nrounds']:
            for eta in params['eta']:
                for gamma in params['gamma']:
                    for max_depth in params['max_depth']:
                        for min_child_weight in params['min_child_weight']:
                            for subsample in params['subsample']:
                                for colsample_bytree in params['colsample_bytree']:
                                    for num_parallel_tree in params['num_parallel_tree']:
                                        for lamda in params['lambda']:
                                            for alpha in params['alpha']:
                                                start = timeit.default_timer()
                                                num_iter += 1; 
                                                print('Inicio de iteracion ' + str(num_iter) + '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = '  + str(eta) + ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) + ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) + ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) + ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + '\n')
                                               
                                                #Entrenar modelo
                                                model = XGBClassifier(nthread = nthread, scale_pos_weight = scale_pos_weight,
                                                                      random_state = random_state, n_estimators = nrounds,
                                                                      learning_rate = eta, gamma = gamma,
                                                                      max_depth = max_depth, min_child_weight = min_child_weight ,
                                                                      subsample = subsample, colsample_bytree = colsample_bytree,
                                                                      num_parallel_tree = num_parallel_tree,
                                                                      reg_lambda = lamda, reg_alpha = alpha)
                                                model.fit(X_train, np.array(y_train))

                                                #Generar predicciones
                                                pred_train_p = model.predict_proba(X_train)
                                                pred_val_p = model.predict_proba(X_val)

                                                #Calcular métricas de evaluación
                                                auc_train = metric(y_train, pred_train_p[:, 1])
                                                auc_val = metric(y_val, pred_val_p[:, 1])    
                                                time = timeit.default_timer() - start

                                                print('Fin de iteracion ' + str(num_iter) + '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = ' + str(eta) + ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) + ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) + ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) + ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + '. AUC train = '  + str(auc_train) + 
                                                      ' -  AUC val = '  + str(auc_val)  + ' -  time = '  + str(time)  + '\n')
                                                grid_results = grid_results.append(pd.DataFrame(data={'model':'xgboost',
                                                                                                      'params': [{'nrounds':[nrounds], 'eta':[eta],
                                                                                                                  'gamma':[gamma], 'max_depth':[max_depth],
                                                                                                                  'min_child_weight':[min_child_weight],
                                                                                                                  'subsample':[subsample], 
                                                                                                                  'colsample_bytree':[colsample_bytree],
                                                                                                                  'num_parallel_tree':[num_parallel_tree],
                                                                                                                  'lamda':[lamda], 'alpha':[alpha]}],
                                                                                                      'auc_train':[auc_train], 'auc_val':[auc_val], 'time':[time]},
                                                                                                columns=['model', 'params', 'auc_train', 'auc_val', 'time']), ignore_index=True)
# Out:
# Inicio de iteracion 1. Regularizacion = l1, Lambda = 1
#
# Fin de iteracion 1. Regularizacion = l1, Lambda = 1. AUC train = 0.7014829351711633 -  AUC val = 0.7397325389783242 -  time = 0.07228157599999463
#
# Inicio de iteracion 2. Regularizacion = l1, Lambda = 10
#
# Fin de iteracion 2. Regularizacion = l1, Lambda = 10. AUC train = 0.7015488662937438 -  AUC val = 0.7404297122575738 -  time = 0.2084588369999949
#
# Inicio de iteracion 3. Regularizacion = l1, Lambda = 100
#
# Fin de iteracion 3. Regularizacion = l1, Lambda = 100. AUC train = 0.7015797715074532 -  AUC val = 0.7405881607301306 -  time = 0.1352711430000113
#
# Inicio de iteracion 4. Regularizacion = l2, Lambda = 1
#
# Fin de iteracion 4. Regularizacion = l2, Lambda = 1. AUC train = 0.7015184761669293 -  AUC val = 0.7401128153124604 -  time = 0.055360970999998926
#
# Inicio de iteracion 5. Regularizacion = l2, Lambda = 10
#
# Fin de iteracion 5. Regularizacion = l2, Lambda = 10. AUC train = 0.7015540171626954 -  AUC val = 0.7403663328685511 -  time = 0.05076770799999508
#
# Inicio de iteracion 6. Regularizacion = l2, Lambda = 100
#
# Fin de iteracion 6. Regularizacion = l2, Lambda = 100. AUC train = 0.7015813167681388 -  AUC val = 0.7403980225630625 -  time = 0.06975817099998949
#
# Inicio de iteracion 7. Regularizacion = none, Lambda = 1
#
# Fin de iteracion 7. Regularizacion = none, Lambda = 1. AUC train = 0.704121725335064 -  AUC val = 0.7358663962479401 -  time = 0.09860549600000468
#
# Inicio de iteracion 8. Regularizacion = none, Lambda = 10
#
# Fin de iteracion 8. Regularizacion = none, Lambda = 10. AUC train = 0.704121725335064 -  AUC val = 0.7358663962479401 -  time = 0.09690488100000039
#
# Inicio de iteracion 9. Regularizacion = none, Lambda = 100
#
# Fin de iteracion 9. Regularizacion = none, Lambda = 100. AUC train = 0.704121725335064 -  AUC val = 0.7358663962479401 -  time = 0.09351563399999918
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# Inicio de iteracion 10. C = 2.0232209027962953, gamma = 0.9187812103811747
#
# Fin de iteracion 10. C = 2.0232209027962953, gamma = 0.9187812103811747. AUC train = 0.9449176376054642 -  AUC val = 0.6406071745468375 -  time = 5.054570920999993
#
# Inicio de iteracion 11. C = 2.0232209027962953, gamma = 3.26e-09
#
# Fin de iteracion 11. C = 2.0232209027962953, gamma = 3.26e-09. AUC train = 0.6315629796746711 -  AUC val = 0.6529027760172392 -  time = 2.0495097099999953
#
# Inicio de iteracion 12. C = 2.0232209027962953, gamma = 3.255e-09
#
# Fin de iteracion 12. C = 2.0232209027962953, gamma = 3.255e-09. AUC train = 0.6241019459982899 -  AUC val = 0.6593040943085309 -  time = 2.0545989750000047
#
# Inicio de iteracion 13. C = 2.0232209027962953, gamma = 3.25e-09
#
# Fin de iteracion 13. C = 2.0232209027962953, gamma = 3.25e-09. AUC train = 0.6230094466936572 -  AUC val = 0.6598745088097351 -  time = 2.0515652109999962
#
# Inicio de iteracion 14. C = 0.005, gamma = 0.9187812103811747
#
# Fin de iteracion 14. C = 0.005, gamma = 0.9187812103811747. AUC train = 0.9192977305271399 -  AUC val = 0.6497971859551274 -  time = 3.4370985310000037
#
# Inicio de iteracion 15. C = 0.005, gamma = 3.26e-09
#
# Fin de iteracion 15. C = 0.005, gamma = 3.26e-09. AUC train = 0.6549525604969557 -  AUC val = 0.6893934592470528 -  time = 2.0806822119999993
#
# Inicio de iteracion 16. C = 0.005, gamma = 3.255e-09
#
# Fin de iteracion 16. C = 0.005, gamma = 3.255e-09. AUC train = 0.6394453544312926 -  AUC val = 0.6713144885283305 -  time = 2.1204555939999636
#
# Inicio de iteracion 17. C = 0.005, gamma = 3.25e-09
#
# Fin de iteracion 17. C = 0.005, gamma = 3.25e-09. AUC train = 0.6539229017935326 -  AUC val = 0.6863987831157308 -  time = 2.111372958000004
#
# Inicio de iteracion 18. C = 0.0045, gamma = 0.9187812103811747
#
# Fin de iteracion 18. C = 0.0045, gamma = 0.9187812103811747. AUC train = 0.9142436979118377 -  AUC val = 0.6411775890480416 -  time = 3.468031950000011
#
# Inicio de iteracion 19. C = 0.0045, gamma = 3.26e-09
#
# Fin de iteracion 19. C = 0.0045, gamma = 3.26e-09. AUC train = 0.652215903822975 -  AUC val = 0.676131322094055 -  time = 2.0530386130000124
#
# Inicio de iteracion 20. C = 0.0045, gamma = 3.255e-09
#
# Fin de iteracion 20. C = 0.0045, gamma = 3.255e-09. AUC train = 0.6197968497285492 -  AUC val = 0.6400050703511219 -  time = 2.0949591950000013
#
# Inicio de iteracion 21. C = 0.0045, gamma = 3.25e-09
#
# Fin de iteracion 21. C = 0.0045, gamma = 3.25e-09. AUC train = 0.6343470243430066 -  AUC val = 0.6507478767904677 -  time = 2.042417427000032
#
# Inicio de iteracion 22. C = 0.004, gamma = 0.9187812103811747
#
# Fin de iteracion 22. C = 0.004, gamma = 0.9187812103811747. AUC train = 0.917288891636019 -  AUC val = 0.6491000126758778 -  time = 3.2595999850000226
#
# Inicio de iteracion 23. C = 0.004, gamma = 3.26e-09
#
# Fin de iteracion 23. C = 0.004, gamma = 3.26e-09. AUC train = 0.6288057195248838 -  AUC val = 0.6438712130815059 -  time = 2.0832829299999958
#
# Inicio de iteracion 24. C = 0.004, gamma = 3.255e-09
#
# Fin de iteracion 24. C = 0.004, gamma = 3.255e-09. AUC train = 0.6454602816495142 -  AUC val = 0.6730574217264547 -  time = 2.0327291840000044
#
# Inicio de iteracion 25. C = 0.004, gamma = 3.25e-09
#
# Fin de iteracion 25. C = 0.004, gamma = 3.25e-09. AUC train = 0.6422203850789628 -  AUC val = 0.6600329572822917 -  time = 2.05838555400004
#
# Inicio de iteracion 26. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 26. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.8075326307548083 -  AUC val = 0.72349157054126 -  time = 0.0920717309999759
#
# Inicio de iteracion 27. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 27. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.7424985320023488 -  AUC val = 0.703606287235391 -  time = 0.03806894399997418
#
# Inicio de iteracion 28. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 28. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.7653578308660671 -  AUC val = 0.6742140955761187 -  time = 0.043581633000030706
#
# Inicio de iteracion 29. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 29. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.8016168577639047 -  AUC val = 0.7306217518063127 -  time = 0.09655019500002027
#
# Inicio de iteracion 30. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 30. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.7347611542067147 -  AUC val = 0.6834516415261757 -  time = 0.038582869999970626
#
# Inicio de iteracion 31. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 31. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.7488827765243997 -  AUC val = 0.6882050957028772 -  time = 0.04106180400003723
#
# Inicio de iteracion 32. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 32. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.7815320744609615 -  AUC val = 0.7294492331093929 -  time = 0.0884071629999994
#
# Inicio de iteracion 33. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 33. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.7086869404868601 -  AUC val = 0.6664025858790721 -  time = 0.0416218830000048
#
# Inicio de iteracion 34. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 34. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.7238044833163355 -  AUC val = 0.6835784003042211 -  time = 0.044157519000009415
#
# Inicio de iteracion 35. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 35. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.8068205231222507 -  AUC val = 0.7212732919254659 -  time = 0.09367291999996041
#
# Inicio de iteracion 36. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 36. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.7399712581512501 -  AUC val = 0.6553428824946127 -  time = 0.04561440200001243
#
# Inicio de iteracion 37. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 37. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.7648901319652626 -  AUC val = 0.669603245024718 -  time = 0.04623549100000446
#
# Inicio de iteracion 38. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 38. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.8016168577639047 -  AUC val = 0.7306217518063127 -  time = 0.08862414600002921
#
# Inicio de iteracion 39. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 39. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.7347611542067147 -  AUC val = 0.6834516415261757 -  time = 0.041802382000014404
#
# Inicio de iteracion 40. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 40. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.7488827765243997 -  AUC val = 0.6882050957028772 -  time = 0.04120918600000323
#
# Inicio de iteracion 41. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 41. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.7815320744609615 -  AUC val = 0.7294492331093929 -  time = 0.09762760699999262
#
# Inicio de iteracion 42. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 42. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.7086869404868601 -  AUC val = 0.6664025858790721 -  time = 0.03954103199998826
#
# Inicio de iteracion 43. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 43. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.7238044833163355 -  AUC val = 0.6835784003042211 -  time = 0.04549143099995945
#
# Inicio de iteracion 44. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 44. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.7962254432322733 -  AUC val = 0.7173596146533147 -  time = 0.09255837500001007
#
# Inicio de iteracion 45. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 45. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.7322282143997692 -  AUC val = 0.6557865382177716 -  time = 0.044496884000011505
#
# Inicio de iteracion 46. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 46. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.7512390415263055 -  AUC val = 0.6468025098238054 -  time = 0.04618899600001214
#
# Inicio de iteracion 47. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 47. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.7960933234436649 -  AUC val = 0.7228894663455444 -  time = 0.09196979999995847
#
# Inicio de iteracion 48. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 48. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.7303071978242729 -  AUC val = 0.6570382811509696 -  time = 0.0450732250000101
#
# Inicio de iteracion 49. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 49. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.7441643230212936 -  AUC val = 0.6864780073520091 -  time = 0.048206192000009196
#
# Inicio de iteracion 50. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 50. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.7815320744609615 -  AUC val = 0.7294492331093929 -  time = 0.09163751999994929
#
# Inicio de iteracion 51. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 51. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.7086869404868601 -  AUC val = 0.6664025858790721 -  time = 0.03994487399995705
#
# Inicio de iteracion 52. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 52. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.7238044833163355 -  AUC val = 0.6835784003042211 -  time = 0.04334455700001172
#
# Inicio de iteracion 53. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 53. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9974127185256152 -  AUC val = 0.6660539992394473 -  time = 0.15859838799997306
#
# Inicio de iteracion 54. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 54. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9984235765573651 -  AUC val = 0.6731049562682214 -  time = 0.05443536100000301
#
# Inicio de iteracion 55. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 55. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9983859752140186 -  AUC val = 0.6886487514260363 -  time = 0.06245913200001496
#
# Inicio de iteracion 56. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 56. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.944040959709903 -  AUC val = 0.6943687412853341 -  time = 0.14316458100000773
#
# Inicio de iteracion 57. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 57. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.8468345334857991 -  AUC val = 0.6956521739130436 -  time = 0.043293414000004304
#
# Inicio de iteracion 58. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 58. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.877688238505836 -  AUC val = 0.6973000380276334 -  time = 0.054545118000021375
#
# Inicio de iteracion 59. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 59. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.8337307228729488 -  AUC val = 0.7307326657371023 -  time = 0.1132748239999728
#
# Inicio de iteracion 60. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 60. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.7364874679358407 -  AUC val = 0.6648497908480162 -  time = 0.04114620699999705
#
# Inicio de iteracion 61. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 61. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.7638818493679884 -  AUC val = 0.7061889973380657 -  time = 0.047591968999995515
#
# Inicio de iteracion 62. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 62. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9901837314955033 -  AUC val = 0.6687159335784003 -  time = 0.15504666900000075
#
# Inicio de iteracion 63. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 63. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.978002441511883 -  AUC val = 0.676273925719356 -  time = 0.05520373600000994
#
# Inicio de iteracion 64. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 64. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.980029050900887 -  AUC val = 0.6532672075041196 -  time = 0.057019871999955285
#
# Inicio de iteracion 65. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 65. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.944040959709903 -  AUC val = 0.6943687412853341 -  time = 0.13777369900003578
#
# Inicio de iteracion 66. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 66. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.8468345334857991 -  AUC val = 0.6956521739130436 -  time = 0.04379113900000675
#
# Inicio de iteracion 67. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 67. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.877688238505836 -  AUC val = 0.6973000380276334 -  time = 0.04788855900000044
#
# Inicio de iteracion 68. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 68. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.8337307228729488 -  AUC val = 0.7307326657371023 -  time = 0.11750816900001837
#
# Inicio de iteracion 69. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 69. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.7364874679358407 -  AUC val = 0.6648497908480162 -  time = 0.03810516999999436
#
# Inicio de iteracion 70. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 70. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.7638818493679884 -  AUC val = 0.7061889973380657 -  time = 0.0447264480000058
#
# Inicio de iteracion 71. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 71. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9299373654335487 -  AUC val = 0.6949866903283053 -  time = 0.141824057000008
#
# Inicio de iteracion 72. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 72. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.8863151713694102 -  AUC val = 0.7065851185194575 -  time = 0.0465752090000251
#
# Inicio de iteracion 73. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 73. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.8948923983476011 -  AUC val = 0.7140163518823679 -  time = 0.04986763799996652
#
# Inicio de iteracion 74. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 74. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9087618856301057 -  AUC val = 0.6979338319178603 -  time = 0.13190915199999154
#
# Inicio de iteracion 75. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 75. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.8145741261550825 -  AUC val = 0.6771295474711624 -  time = 0.04290065800000775
#
# Inicio de iteracion 76. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 76. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.850067991470161 -  AUC val = 0.6892667004690074 -  time = 0.045672923999973136
#
# Inicio de iteracion 77. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 77. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.8337307228729488 -  AUC val = 0.7307326657371023 -  time = 0.11779212099997949
#
# Inicio de iteracion 78. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 78. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.7364874679358407 -  AUC val = 0.6648497908480162 -  time = 0.0387291540000092
#
# Inicio de iteracion 79. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 79. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.7638818493679884 -  AUC val = 0.7061889973380657 -  time = 0.04537766499998952
#
# Inicio de iteracion 80. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 80. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.8268599787784201 -  AUC val = 0.7502852072506021 -  time = 0.8588800999999648
#
# Inicio de iteracion 81. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 81. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.7656133139660661 -  AUC val = 0.6977436937507923 -  time = 0.3027487880000308
#
# Inicio de iteracion 82. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 82. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.7827631321403921 -  AUC val = 0.7140955761186463 -  time = 0.333652088000008
#
# Inicio de iteracion 83. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 83. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.8184383080425668 -  AUC val = 0.754056280897452 -  time = 0.8473713539999608
#
# Inicio de iteracion 84. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 84. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.7497045976656262 -  AUC val = 0.7054284446697934 -  time = 0.29085544399998753
#
# Inicio de iteracion 85. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 85. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.7634615384615384 -  AUC val = 0.7201166180758019 -  time = 0.31854084999997667
#
# Inicio de iteracion 86. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 86. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.792371563082692 -  AUC val = 0.7577322854607682 -  time = 0.8211401159999809
#
# Inicio de iteracion 87. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 87. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.7199678585777423 -  AUC val = 0.6927050323234885 -  time = 0.2839974870000219
#
# Inicio de iteracion 88. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 88. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.7369747401386615 -  AUC val = 0.6996450754214729 -  time = 0.3189692789999867
#
# Inicio de iteracion 89. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 89. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.8247450319868961 -  AUC val = 0.7483204461908988 -  time = 0.8209452910000437
#
# Inicio de iteracion 90. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 90. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.7643178704247405 -  AUC val = 0.6944479655216123 -  time = 0.2981623119999881
#
# Inicio de iteracion 91. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 91. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.7796450536205458 -  AUC val = 0.706078083407276 -  time = 0.3184305759999688
#
# Inicio de iteracion 92. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 92. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.8184383080425668 -  AUC val = 0.754056280897452 -  time = 0.8345948999999564
#
# Inicio de iteracion 93. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 93. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.7497045976656262 -  AUC val = 0.7054284446697934 -  time = 0.2950372399999992
#
# Inicio de iteracion 94. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 94. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.7634615384615384 -  AUC val = 0.7201166180758019 -  time = 0.31336731999999756
#
# Inicio de iteracion 95. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 95. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.792371563082692 -  AUC val = 0.7577322854607682 -  time = 0.8096499819999963
#
# Inicio de iteracion 96. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 96. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.7199678585777423 -  AUC val = 0.6927050323234885 -  time = 0.2845833449999873
#
# Inicio de iteracion 97. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 97. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.7369747401386615 -  AUC val = 0.6996450754214729 -  time = 0.31686646999997947
#
# Inicio de iteracion 98. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 98. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.8116739293918884 -  AUC val = 0.7506654835847383 -  time = 0.8312369799999715
#
# Inicio de iteracion 99. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 99. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.7526423957721667 -  AUC val = 0.6982507288629738 -  time = 0.2956529260000025
#
# Inicio de iteracion 100. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 100. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.7643946183721194 -  AUC val = 0.703748890860692 -  time = 0.3097826590000068
#
# Inicio de iteracion 101. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 101. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.8109373551318108 -  AUC val = 0.7531055900621118 -  time = 0.835837649000041
#
# Inicio de iteracion 102. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 102. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.7427777090995251 -  AUC val = 0.6904550640131828 -  time = 0.2911010700000247
#
# Inicio de iteracion 103. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 103. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.7601927970248581 -  AUC val = 0.7248859170997591 -  time = 0.3334829440000249
#
# Inicio de iteracion 104. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 104. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.792371563082692 -  AUC val = 0.7577322854607682 -  time = 0.7967785280000044
#
# Inicio de iteracion 105. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 105. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.7199678585777423 -  AUC val = 0.6927050323234885 -  time = 0.29928584799995406
#
# Inicio de iteracion 106. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 106. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.7369747401386615 -  AUC val = 0.6996450754214729 -  time = 0.3145387989999904
#
# Inicio de iteracion 107. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 107. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9999989698262097 -  AUC val = 0.7040499429585498 -  time = 1.4872031419999985
#
# Inicio de iteracion 108. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 108. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9999984547393145 -  AUC val = 0.7024179236912156 -  time = 0.45945351499995013
#
# Inicio de iteracion 109. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 109. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9999984547393146 -  AUC val = 0.7258999873241222 -  time = 0.49558593500000825
#
# Inicio de iteracion 110. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 110. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9672095682541645 -  AUC val = 0.7332678412980098 -  time = 1.336012003999997
#
# Inicio de iteracion 111. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 111. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.8941429469151446 -  AUC val = 0.7209405501330968 -  time = 0.36321284299998524
#
# Inicio de iteracion 112. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 112. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9099040908201212 -  AUC val = 0.7238560020281406 -  time = 0.4241263940000408
#
# Inicio de iteracion 113. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 113. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.8555683468801186 -  AUC val = 0.7515844847255673 -  time = 1.0087187530000392
#
# Inicio de iteracion 114. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 114. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.7484689042041393 -  AUC val = 0.7063632906578781 -  time = 0.30731962300001214
#
# Inicio de iteracion 115. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 115. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.7745776287459696 -  AUC val = 0.7111642793763467 -  time = 0.33882975599999554
#
# Inicio de iteracion 116. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 116. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9995395123157277 -  AUC val = 0.7035429078463683 -  time = 1.4612452889999759
#
# Inicio de iteracion 117. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 117. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9961497254586849 -  AUC val = 0.721891240968437 -  time = 0.41208466500000895
#
# Inicio de iteracion 118. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 118. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.996541706585901 -  AUC val = 0.7232063632906578 -  time = 0.45806341899998415
#
# Inicio de iteracion 119. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 119. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9672095682541645 -  AUC val = 0.7332678412980098 -  time = 1.266801504
#
# Inicio de iteracion 120. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 120. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.8941429469151446 -  AUC val = 0.7209405501330968 -  time = 0.35031175799997527
#
# Inicio de iteracion 121. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 121. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9099040908201212 -  AUC val = 0.7238560020281406 -  time = 0.38634677599998213
#
# Inicio de iteracion 122. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 122. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.8555683468801186 -  AUC val = 0.7515844847255673 -  time = 1.0262342049999802
#
# Inicio de iteracion 123. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 123. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.7484689042041393 -  AUC val = 0.7063632906578781 -  time = 0.30054577800001425
#
# Inicio de iteracion 124. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 124. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.7745776287459696 -  AUC val = 0.7111642793763467 -  time = 0.32958575100002463
#
# Inicio de iteracion 125. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 125. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.952759320497368 -  AUC val = 0.7308277348206362 -  time = 1.4038881829999923
#
# Inicio de iteracion 126. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 126. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9185127380989173 -  AUC val = 0.7324122195462035 -  time = 0.6612142050000216
#
# Inicio de iteracion 127. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 127. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9228487395823675 -  AUC val = 0.7206236531879833 -  time = 0.41284626100002697
#
# Inicio de iteracion 128. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 128. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9346972834317149 -  AUC val = 0.738052985169223 -  time = 1.245897130000003
#
# Inicio de iteracion 129. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 129. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.8567035983970496 -  AUC val = 0.7178349600709849 -  time = 0.3298981670000103
#
# Inicio de iteracion 130. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 130. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.874852942691432 -  AUC val = 0.7203701356318926 -  time = 0.38486445000000913
#
# Inicio de iteracion 131. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 131. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.8555683468801186 -  AUC val = 0.7515844847255673 -  time = 1.0301946199999747
#
# Inicio de iteracion 132. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 132. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.7484689042041393 -  AUC val = 0.7063632906578781 -  time = 0.31506075900000496
#
# Inicio de iteracion 133. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 133. n_trees = 100, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.7745776287459696 -  AUC val = 0.7111642793763467 -  time = 0.3329463439999927
#
# Inicio de iteracion 134. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 134. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.8256781118974771 -  AUC val = 0.7518696919761695 -  time = 8.779280589999985
#
# Inicio de iteracion 135. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 135. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.7703152846885271 -  AUC val = 0.7024337685384713 -  time = 2.745232391000002
#
# Inicio de iteracion 136. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 136. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.7843944123373613 -  AUC val = 0.7133667131448853 -  time = 3.041611011000043
#
# Inicio de iteracion 137. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 137. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.8173986051446879 -  AUC val = 0.7554506274559514 -  time = 8.097377857999959
#
# Inicio de iteracion 138. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 138. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.7501367555706647 -  AUC val = 0.6993281784763595 -  time = 2.7393777540000315
#
# Inicio de iteracion 139. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 139. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.765667913176953 -  AUC val = 0.7167892001521105 -  time = 3.16242237900002
#
# Inicio de iteracion 140. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 140. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.7919888535195887 -  AUC val = 0.7560844213461781 -  time = 7.79749893799999
#
# Inicio de iteracion 141. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 141. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.7215790503858002 -  AUC val = 0.6908670300418305 -  time = 2.726266097000007
#
# Inicio de iteracion 142. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 142. n_trees = 1000, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.7366283442016668 -  AUC val = 0.7045252883762201 -  time = 2.8939243099999885
#
# Inicio de iteracion 143. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 143. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.8235626500190583 -  AUC val = 0.7527886931169983 -  time = 8.226131508000037
#
# Inicio de iteracion 144. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 144. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.7667060708141463 -  AUC val = 0.7005006971732792 -  time = 2.735187594000024
#
# Inicio de iteracion 145. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 145. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.7806347930895943 -  AUC val = 0.7159969577893269 -  time = 3.0138836519999472
#
# Inicio de iteracion 146. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 146. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.8173986051446879 -  AUC val = 0.7554506274559514 -  time = 8.195824533000007
#
# Inicio de iteracion 147. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 147. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.7501367555706647 -  AUC val = 0.6993281784763595 -  time = 2.7702376240000035
#
# Inicio de iteracion 148. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 148. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.765667913176953 -  AUC val = 0.7167892001521105 -  time = 3.0503624689999924
#
# Inicio de iteracion 149. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 149. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.7919888535195887 -  AUC val = 0.7560844213461781 -  time = 7.835912024000038
#
# Inicio de iteracion 150. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 150. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.7215790503858002 -  AUC val = 0.6908670300418305 -  time = 2.647217256000033
#
# Inicio de iteracion 151. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 151. n_trees = 1000, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.7366283442016668 -  AUC val = 0.7045252883762201 -  time = 2.9349881809999943
#
# Inicio de iteracion 152. n_trees = 1000, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 152. n_trees = 1000, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.8108219756672952 -  AUC val = 0.7502535175560908 -  time = 8.086490401999981
#
# Inicio de iteracion 153. n_trees = 1000, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 153. n_trees = 1000, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.7551614282329429 -  AUC val = 0.700120420839143 -  time = 2.8031510799999637
#
# Inicio de iteracion 154. n_trees = 1000, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# ...
#
# Inicio de iteracion 1188. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1188. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.6099610079220364 -  AUC val = 0.6448377487641019 -  time = 0.12049182200007635
#
# Inicio de iteracion 1189. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1189. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.596411904688321 -  AUC val = 0.6439504373177842 -  time = 0.1343103809999775
#
# Inicio de iteracion 1190. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1190. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.6236986329593802 -  AUC val = 0.6448377487641019 -  time = 0.11781312800007981
#
# Inicio de iteracion 1191. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1191. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.596411904688321 -  AUC val = 0.6439504373177842 -  time = 0.13807588500003476
#
# Inicio de iteracion 1192. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1192. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.6397639356759486 -  AUC val = 0.6555964000507035 -  time = 0.8129997080000066
#
# Inicio de iteracion 1193. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1193. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.6387162489311946 -  AUC val = 0.6519996197236659 -  time = 0.8030176670001765
#
# Inicio de iteracion 1194. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1194. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.6394036323927847 -  AUC val = 0.6553428824946127 -  time = 0.8135011320000558
#
# Inicio de iteracion 1195. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1195. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.6385377713220219 -  AUC val = 0.6525224996831032 -  time = 0.8106991270001345
#
# Inicio de iteracion 1196. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1196. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.7453013773423576 -  AUC val = 0.6913265306122447 -  time = 0.12333762199978082
#
# Inicio de iteracion 1197. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1197. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.7348734431498594 -  AUC val = 0.7140638864241349 -  time = 0.1335920100000294
#
# Inicio de iteracion 1198. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1198. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.7436154979345015 -  AUC val = 0.6979813664596273 -  time = 0.12392171799979224
#
# Inicio de iteracion 1199. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1199. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.7301418549309269 -  AUC val = 0.7177874255292178 -  time = 0.1275934700001926
#
# Inicio de iteracion 1200. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1200. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.7230828465762174 -  AUC val = 0.7379579160856891 -  time = 0.8137748540000302
#
# Inicio de iteracion 1201. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1201. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.7145895787619372 -  AUC val = 0.7356762580808722 -  time = 0.8073692440000286
#
# Inicio de iteracion 1202. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1202. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.7231145244202697 -  AUC val = 0.7397325389783241 -  time = 0.8056813480000073
#
# Inicio de iteracion 1203. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1203. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.7152313770333055 -  AUC val = 0.7373241221954621 -  time = 0.7679460089998429
#
# Inicio de iteracion 1204. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1204. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.8438132913022427 -  AUC val = 0.7103878818608189 -  time = 0.47556118099987543
#
# Inicio de iteracion 1205. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1205. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.8206397894324773 -  AUC val = 0.7455000633793891 -  time = 0.4832970289999139
#
# Inicio de iteracion 1206. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1206. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.850296432508164 -  AUC val = 0.7128913677272151 -  time = 0.41603723899993383
#
# Inicio de iteracion 1207. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1207. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.7970887288685601 -  AUC val = 0.7368329319305362 -  time = 0.47425370199994177
#
# Inicio de iteracion 1208. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1208. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.8438122611284523 -  AUC val = 0.7103878818608189 -  time = 7.472324997999976
#
# Inicio de iteracion 1209. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1209. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.8206392743455821 -  AUC val = 0.7455000633793891 -  time = 7.488390320999997
#
# Inicio de iteracion 1210. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1210. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.8502959174212689 -  AUC val = 0.7128913677272151 -  time = 6.326040104999947
#
# Inicio de iteracion 1211. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1211. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.7970892439554552 -  AUC val = 0.7368329319305362 -  time = 7.614251666999962

# %% [markdown]
# ## Resultados

# %%
#por tiempo
grid_results.groupby(['model'], sort=False)['time'].mean().sort_values()
# Out:
# model
# Logistic Regression    0.097880
# xgboost                1.177746
# random forest          2.085833
# SVM                    2.503269
# Name: time, dtype: float64

# %%
#por el AUC
grid_results.groupby(['model'], sort=False)['auc_val'].max().sort_values()
# Out:
# model
# SVM                    0.689393
# Logistic Regression    0.740588
# random forest          0.758017
# xgboost                0.769901
# Name: auc_val, dtype: float64

# %%
#Elegimos la mejor combinación de modelo + hiperparámetros
best_params = grid_results.iloc[grid_results['auc_val'].idxmax()]

# %% [markdown]
# # Entrenamiento del modelo final

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))

#Combinamos train y validación
X_train = pd.concat((X_train,X_val), axis = 0)
y_train = np.concatenate((y_train, y_val), axis = 0)

del X_val, y_val

print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
# Out:
# Train data size = (3361, 19)
# Train target size = (3361,)
# Validation data size = (420, 19)
# Validation target size = (420,)
# Train data size = (3781, 19)
# Train target size = (3781,)

# %%
#Regresión Logística
if best_params['model'] == 'logistic regression':       

    #Entrenar modelo
    if best_params['params']['regularization'] == 'l1':
        model = LogisticRegression(penalty = best_params['params']['regularization'][0], 
                                   solver = 'liblinear', C = best_params['params']['penalty'][0], random_state = random_state)
    else:
        model = LogisticRegression(penalty = best_params['params']['regularization'][0],
                                   solver = 'lbfgs', C = best_params['params']['penalty'][0], random_state = random_state)


#SVM
elif best_params['model'] == 'SVM':

    model = SVC(C = best_params['params']['C'][0], gamma = best_params['params']['gamma_kernel'][0], 
                probability = True, random_state = random_state)             


#Random Forest
elif best_params['model'] == 'random forest':
    model = RandomForestClassifier(n_estimators = int(best_params['params']['n_trees'][0]), max_depth = int(best_params['params']['max_depth'][0]),
                                                      min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                      min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                      max_features = int(best_params['params']['max_features'][0]), random_state = random_state)


# XGBOOST
elif best_params['model'] == 'xgboost':
    model = XGBClassifier(nthread = nthread, scale_pos_weight = scale_pos_weight, random_state = random_state,
                          n_estimators = int(best_params['params']['nrounds'][0]), learning_rate = best_params['params']['eta'][0], 
                          gamma = best_params['params']['gamma'][0], max_depth = int(best_params['params']['max_depth'][0]),
                          min_child_weight = best_params['params']['min_child_weight'][0], subsample = best_params['params']['subsample'][0],
                          colsample_bytree = best_params['params']['colsample_bytree'][0],
                          num_parallel_tree  = int(best_params['params']['num_parallel_tree'][0]),
                          reg_lambda = best_params['params']['lamda'][0], reg_alpha = best_params['params']['alpha'][0])

#Entrenar modelo
model.fit(X_train, np.array(y_train))

#Generar predicciones
pred_train_p = model.predict_proba(X_train)
pred_test_p = model.predict_proba(X_test)

#Calcular métricas de evaluación
auc_train = metric(y_train, pred_train_p[:, 1])
auc_test = metric(y_test, pred_test_p[:, 1]) 

results = pd.DataFrame()
results = results.append(pd.DataFrame(data={'model':best_params['model'],'auc_train':[auc_train],
                                            'auc_test':[auc_test]}, columns=['model',  'auc_train', 'auc_test']), ignore_index=True)

# %%
results
# Out:
#      model  auc_train  auc_test
# 0  xgboost   0.771737  0.659341
