# %% [markdown]
# # **PCA**

# %% [markdown]
# ## Import data

# %%
import pandas as pd                  
import numpy as np  
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.preprocessing import scale
from sklearn import decomposition

# %%
df = pd.read_csv('/content/total_merged_test.csv')
df = df.drop(columns=['customerid'] + ['systemloanid'])
y = df['good_bad_flag']

# %% [markdown]
# **Dummies**

# %%
dummy_int = pd.get_dummies(df[['interest_interval']])
dummy_bank_name = pd.get_dummies(df[['bank_name_clients']], drop_first=True)
dummy_td = pd.get_dummies(df[['termdays']], drop_first=True)
dummy_age = pd.get_dummies(df[['age_interval']])
dummy_state = pd.get_dummies(df[['state']], drop_first=True)
dummy_loan = pd.get_dummies(df[['loan_interval']], drop_first=True)
dummy_loannum = pd.get_dummies(df[['loannumber']], drop_first=True)

df = pd.concat([df, dummy_int, dummy_bank_name, dummy_td, dummy_age, dummy_state, dummy_loan, dummy_loannum], axis=1)
df = df.drop(['interest_interval','bank_name_clients', 'termdays', 'age_interval','state','loan_interval','loannumber'], 1)

df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   # Remove the CWD from sys.path while we load stuff.
#    loanamount  interest  good_bad_flag  avg_loanamount  avg_paym_span_hrs  \
# 0     20000.0    4500.0              1         14000.0               12.8
# 1     10000.0    3000.0              1         10000.0               13.0
# 2     10000.0    3000.0              0         10000.0                7.0
# 3     10000.0    3000.0              1         10000.0               18.0
# 4     20000.0    4500.0              1         14000.0                9.0
#
#    avg_active_span_days  avg_interest  max_loannumber   age  \
# 0                  19.0        2700.0             5.0  39.0
# 1                  29.0        3000.0             2.0  42.0
# 2                  57.0        3000.0             1.0  45.0
# 3                  14.0        1500.0             1.0  40.0
# 4                  19.6        2700.0             5.0  37.0
#
#    interest_interval_3000  interest_interval_mas de 3000  \
# 0                       0                              1
# 1                       1                              0
# 2                       1                              0
# 3                       1                              0
# 4                       0                              1
#
#    interest_interval_menos de 3000  bank_name_clients_Multinational Banks  \
# 0                                0                                      1
# 1                                0                                      1
# 2                                0                                      0
# 3                                0                                      1
# 4                                0                                      1
#
#    termdays_Other  age_interval_26-35  age_interval_36-40  age_interval_41-61  \
# 0               0                   0                   1                   0
# 1               0                   0                   0                   1
# 2               0                   0                   0                   1
# 3               0                   0                   1                   0
# 4               0                   0                   1                   0
#
#    state_Other  loan_interval_mas de 10000  loannumber_0-4
# 0            1                           1               0
# 1            1                           0               1
# 2            1                           0               1
# 3            0                           0               1
# 4            0                           1               0

# %% [markdown]
# ## Aplicamos el análisis de componentes principales

# %% [markdown]
# **Estandarizamos**

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X = sc.fit_transform(df.drop(['good_bad_flag'], axis=1))
print(np.mean(X))
print(np.var(X))
# Out:
# -3.2165860061821575e-17
# 0.9999999999999999

# %%
#Apreciamos que los elementos de la diagonal son iguales y que la matriz es simétrica
features = X.T
cov_matrix = np.cov(features)
cov_matrix[:3]
# Out:
# array([[ 1.0011919 ,  0.66232352,  0.89297155, -0.04292662, -0.00216285,
#          0.51145942,  0.86192984,  0.01130977, -0.52803206,  0.75242152,
#         -0.24558433,  0.00565238, -0.03159391,  0.07903358, -0.02530674,
#         -0.05713395, -0.03431531,  0.82125899, -0.72919884],
#        [ 0.66232352,  1.0011919 ,  0.50125701, -0.02622892,  0.14682119,
#          0.52412119,  0.47737314,  0.07783364, -0.17678618,  0.76540745,
#         -0.64059525,  0.05186283, -0.18042357,  0.01434692, -0.01811273,
#          0.00321714,  0.00690335,  0.62960596, -0.51918554],
#        [ 0.89297155,  0.50125701,  1.0011919 , -0.03070116,  0.06893252,
#          0.59620147,  0.86403831, -0.00638712, -0.40871052,  0.56235192,
#         -0.16829517, -0.00997013, -0.0244937 ,  0.07690971, -0.03106334,
#         -0.04912867, -0.04191722,  0.64245864, -0.6857781 ]])

# %% [markdown]
# **Varianza**

# %%
#Representamos el porcentaje de la varianza que explica cada componente

values, vectors = np.linalg.eig(cov_matrix)
explained_variances = []
for i in range(len(values)):
    explained_variances.append(values[i] / np.sum(values))
 
print(np.sum(explained_variances), '\n', explained_variances)

#Vemos que con tres componentes explicaríamos aproximadamente el 53% de la varianza
#6 componentes explicarían aproximadamente el 73%
# Out:
# 0.9999999999999998
#  [0.3154431165810269, 0.1408874075141413, 0.0820256344388089, 0.07736130029575279, 0.06666100816035446, 0.060506890850043134, 0.05246644334831758, 0.049058821342015155, 0.04311688804816982, 0.038610282575631844, 0.027440766246218985, 0.017983117345699955, 0.011976505301191686, 0.007230701905388631, 0.004386304045569257, 0.002225147567352932, 0.0026196644343163436, -5.783985094830804e-17, 1.1793848678530997e-16]

# %% [markdown]
# **Modelo**

# %%
pca = decomposition.PCA(n_components=3)
x = pca.fit_transform(X)

# %% [markdown]
# **Saturación de variables**

# %%
#Vemos la saturación de cada variable en cada uno de los compoenentes
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3'], index= df.drop(['good_bad_flag'],axis=1).columns)
loadings
# Out:
#                                             PC1       PC2       PC3
# loanamount                             0.383484  0.072383 -0.000415
# interest                               0.311376 -0.187052 -0.043391
# avg_loanamount                         0.347385  0.055424  0.058630
# avg_paym_span_hrs                     -0.025437 -0.015041  0.044805
# avg_active_span_days                   0.034922 -0.328916  0.226249
# avg_interest                           0.238668 -0.263433  0.160229
# max_loannumber                         0.353554  0.093011  0.027543
# age                                    0.008751 -0.041384 -0.018218
# interest_interval_3000                -0.213503 -0.454138  0.054894
# interest_interval_mas de 3000          0.354867 -0.019410 -0.101833
# interest_interval_menos de 3000       -0.154359  0.513573  0.051206
# bank_name_clients_Multinational Banks  0.023653 -0.062196 -0.129826
# termdays_Other                        -0.061549  0.479165  0.062291
# age_interval_26-35                     0.034790  0.110327  0.707706
# age_interval_36-40                    -0.021619  0.046484 -0.588687
# age_interval_41-61                    -0.014616 -0.161989 -0.147658
# state_Other                           -0.011828 -0.079255  0.041369
# loan_interval_mas de 10000             0.363670  0.095682 -0.080409
# loannumber_0-4                        -0.342677 -0.093143  0.024474

# %%
#Aquí vemos mejor qué variable pertenece a cada componente
loadings.abs().style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style type="text/css">
# #T_17f4a_row0_col0, #T_17f4a_row1_col0, #T_17f4a_row2_col0, #T_17f4a_row3_col2, #T_17f4a_row4_col1, #T_17f4a_row5_col1, #T_17f4a_row6_col0, #T_17f4a_row7_col1, #T_17f4a_row8_col1, #T_17f4a_row9_col0, #T_17f4a_row10_col1, #T_17f4a_row11_col2, #T_17f4a_row12_col1, #T_17f4a_row13_col2, #T_17f4a_row14_col2, #T_17f4a_row15_col1, #T_17f4a_row16_col1, #T_17f4a_row17_col0, #T_17f4a_row18_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_17f4a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PC1</th>
#       <th class="col_heading level0 col1" >PC2</th>
#       <th class="col_heading level0 col2" >PC3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17f4a_level0_row0" class="row_heading level0 row0" >loanamount</th>
#       <td id="T_17f4a_row0_col0" class="data row0 col0" >0.383484</td>
#       <td id="T_17f4a_row0_col1" class="data row0 col1" >0.072383</td>
#       <td id="T_17f4a_row0_col2" class="data row0 col2" >0.000415</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row1" class="row_heading level0 row1" >interest</th>
#       <td id="T_17f4a_row1_col0" class="data row1 col0" >0.311376</td>
#       <td id="T_17f4a_row1_col1" class="data row1 col1" >0.187052</td>
#       <td id="T_17f4a_row1_col2" class="data row1 col2" >0.043391</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row2" class="row_heading level0 row2" >avg_loanamount</th>
#       <td id="T_17f4a_row2_col0" class="data row2 col0" >0.347385</td>
#       <td id="T_17f4a_row2_col1" class="data row2 col1" >0.055424</td>
#       <td id="T_17f4a_row2_col2" class="data row2 col2" >0.058630</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row3" class="row_heading level0 row3" >avg_paym_span_hrs</th>
#       <td id="T_17f4a_row3_col0" class="data row3 col0" >0.025437</td>
#       <td id="T_17f4a_row3_col1" class="data row3 col1" >0.015041</td>
#       <td id="T_17f4a_row3_col2" class="data row3 col2" >0.044805</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row4" class="row_heading level0 row4" >avg_active_span_days</th>
#       <td id="T_17f4a_row4_col0" class="data row4 col0" >0.034922</td>
#       <td id="T_17f4a_row4_col1" class="data row4 col1" >0.328916</td>
#       <td id="T_17f4a_row4_col2" class="data row4 col2" >0.226249</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row5" class="row_heading level0 row5" >avg_interest</th>
#       <td id="T_17f4a_row5_col0" class="data row5 col0" >0.238668</td>
#       <td id="T_17f4a_row5_col1" class="data row5 col1" >0.263433</td>
#       <td id="T_17f4a_row5_col2" class="data row5 col2" >0.160229</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row6" class="row_heading level0 row6" >max_loannumber</th>
#       <td id="T_17f4a_row6_col0" class="data row6 col0" >0.353554</td>
#       <td id="T_17f4a_row6_col1" class="data row6 col1" >0.093011</td>
#       <td id="T_17f4a_row6_col2" class="data row6 col2" >0.027543</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row7" class="row_heading level0 row7" >age</th>
#       <td id="T_17f4a_row7_col0" class="data row7 col0" >0.008751</td>
#       <td id="T_17f4a_row7_col1" class="data row7 col1" >0.041384</td>
#       <td id="T_17f4a_row7_col2" class="data row7 col2" >0.018218</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row8" class="row_heading level0 row8" >interest_interval_3000</th>
#       <td id="T_17f4a_row8_col0" class="data row8 col0" >0.213503</td>
#       <td id="T_17f4a_row8_col1" class="data row8 col1" >0.454138</td>
#       <td id="T_17f4a_row8_col2" class="data row8 col2" >0.054894</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row9" class="row_heading level0 row9" >interest_interval_mas de 3000</th>
#       <td id="T_17f4a_row9_col0" class="data row9 col0" >0.354867</td>
#       <td id="T_17f4a_row9_col1" class="data row9 col1" >0.019410</td>
#       <td id="T_17f4a_row9_col2" class="data row9 col2" >0.101833</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row10" class="row_heading level0 row10" >interest_interval_menos de 3000</th>
#       <td id="T_17f4a_row10_col0" class="data row10 col0" >0.154359</td>
#       <td id="T_17f4a_row10_col1" class="data row10 col1" >0.513573</td>
#       <td id="T_17f4a_row10_col2" class="data row10 col2" >0.051206</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row11" class="row_heading level0 row11" >bank_name_clients_Multinational Banks</th>
#       <td id="T_17f4a_row11_col0" class="data row11 col0" >0.023653</td>
#       <td id="T_17f4a_row11_col1" class="data row11 col1" >0.062196</td>
#       <td id="T_17f4a_row11_col2" class="data row11 col2" >0.129826</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row12" class="row_heading level0 row12" >termdays_Other</th>
#       <td id="T_17f4a_row12_col0" class="data row12 col0" >0.061549</td>
#       <td id="T_17f4a_row12_col1" class="data row12 col1" >0.479165</td>
#       <td id="T_17f4a_row12_col2" class="data row12 col2" >0.062291</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row13" class="row_heading level0 row13" >age_interval_26-35</th>
#       <td id="T_17f4a_row13_col0" class="data row13 col0" >0.034790</td>
#       <td id="T_17f4a_row13_col1" class="data row13 col1" >0.110327</td>
#       <td id="T_17f4a_row13_col2" class="data row13 col2" >0.707706</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row14" class="row_heading level0 row14" >age_interval_36-40</th>
#       <td id="T_17f4a_row14_col0" class="data row14 col0" >0.021619</td>
#       <td id="T_17f4a_row14_col1" class="data row14 col1" >0.046484</td>
#       <td id="T_17f4a_row14_col2" class="data row14 col2" >0.588687</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row15" class="row_heading level0 row15" >age_interval_41-61</th>
#       <td id="T_17f4a_row15_col0" class="data row15 col0" >0.014616</td>
#       <td id="T_17f4a_row15_col1" class="data row15 col1" >0.161989</td>
#       <td id="T_17f4a_row15_col2" class="data row15 col2" >0.147658</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row16" class="row_heading level0 row16" >state_Other</th>
#       <td id="T_17f4a_row16_col0" class="data row16 col0" >0.011828</td>
#       <td id="T_17f4a_row16_col1" class="data row16 col1" >0.079255</td>
#       <td id="T_17f4a_row16_col2" class="data row16 col2" >0.041369</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row17" class="row_heading level0 row17" >loan_interval_mas de 10000</th>
#       <td id="T_17f4a_row17_col0" class="data row17 col0" >0.363670</td>
#       <td id="T_17f4a_row17_col1" class="data row17 col1" >0.095682</td>
#       <td id="T_17f4a_row17_col2" class="data row17 col2" >0.080409</td>
#     </tr>
#     <tr>
#       <th id="T_17f4a_level0_row18" class="row_heading level0 row18" >loannumber_0-4</th>
#       <td id="T_17f4a_row18_col0" class="data row18 col0" >0.342677</td>
#       <td id="T_17f4a_row18_col1" class="data row18 col1" >0.093143</td>
#       <td id="T_17f4a_row18_col2" class="data row18 col2" >0.024474</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Nuevo dataframe de los componentes**

# %%
#Creamos un dataframe con los tres componentes y la variable target

projected_1 = X.dot(vectors.T[0])
projected_2 = X.dot(vectors.T[1])
projected_3 = X.dot(vectors.T[2])

res = pd.DataFrame(projected_1, columns=['PC1'])
res['PC2'] = projected_2
res['PC3'] = projected_3
res['Y'] = y
res.head()
# Out:
#         PC1       PC2       PC3  Y
# 0 -2.033963  0.112226  1.800107  1
# 1  1.691348  2.347953  0.030756  1
# 2  1.692131  3.287265 -0.897788  0
# 3  2.295393  0.749977  1.688313  1
# 4 -2.083365 -0.037694  1.908369  1

# %% [markdown]
# ##Extraer CSV

# %%
res.to_csv('PCA3_train.csv', index=False)

# %%
#repetimos el proceso con el csv de test (fijarse en el csv que cargamos al principio)
res.to_csv('PCA3_test.csv', index=False)
